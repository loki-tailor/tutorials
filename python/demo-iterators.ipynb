# %%
# string iterator

str1 = "lokeshwar"
itr_str = iter(str1)

for i in range(0,len(str1),1):
    print(next(itr_str))

# print(next(itr_str)) # error

# %%
# tuple iterator
tup = (1, 2, 3, 4)
itr_tup = iter(tup)

print(next(itr_tup))
print(next(itr_tup))
print(next(itr_tup))
print(next(itr_tup))
# print(next(itr_tup)) # error
