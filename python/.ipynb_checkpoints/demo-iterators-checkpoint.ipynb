# %%
# tuple iterator
tup = (1, 2, 3, 4)
itr_tup = iter(tup)

print(next(itr_tup))
print(next(itr_tup))
print(next(itr_tup))
print(next(itr_tup))
# print(next(itr_tup)) # error
# Out:
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-2-69865b4f7ea4> in <module>
#       7 print(next(itr_tup))
#       8 print(next(itr_tup))
# ----> 9 print(next(itr_tup))
#
# StopIteration:
